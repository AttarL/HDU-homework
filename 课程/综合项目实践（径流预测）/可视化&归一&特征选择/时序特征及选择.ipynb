# %%
#导入常用库
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import os
#import missingno as msno
import math
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
data=pd.read_csv(r"D:\jupytercode\综合项目实践\径流预测\processed_data.csv")

# 划分特征和目标变量
#X = data.drop(columns=['Discharge'])
X=data.drop(columns=['Swe','Date'])
y = data['Discharge']

# 划分数据集
train_years = 1461  # 前4年的数据
X_train, X_test = X[:train_years], X[train_years:]
y_train, y_test = y[:train_years], y[train_years:]

# %%
data.head()
# Out:
#          Date  Discharge     Dayl   Prcp    Srad  Swe  Tmax  Tmin      Vp  \
# 0  2000-01-08       49.0  32486.4   1.77  161.63  0.0  1.54 -6.54  374.92
# 1  2000-01-09       46.0  32486.4   0.00  168.24  0.0  0.82 -6.76  369.02
# 2  2000-01-10       83.0  32832.0   0.00  150.35  0.0  4.09 -2.70  503.67
# 3  2000-01-11      120.0  32832.0  18.22   72.23  0.0  4.75  0.67  637.65
# 4  2000-01-12       79.0  32832.0   1.19  138.55  0.0  4.07 -2.58  507.84
#
#    Prcp_lag_1  ...  Tmax_lag_6  Srad_lag_6  Discharge_lag_6  Prcp_lag_7  \
# 0        0.00  ...        6.99      214.92             39.0        0.00
# 1        1.77  ...       11.65      176.35             44.0        0.00
# 2        0.00  ...       11.61      143.33             77.0        2.58
# 3        0.00  ...       11.80      188.99             91.0        8.58
# 4       18.22  ...       -2.70      208.24             55.0       13.93
#
#    Tmax_lag_7  Srad_lag_7  Discharge_lag_7  Year  Month  Day
# 0        1.56      204.85             39.0  2000      1    8
# 1        6.99      214.92             39.0  2000      1    9
# 2       11.65      176.35             44.0  2000      1   10
# 3       11.61      143.33             77.0  2000      1   11
# 4       11.80      188.99             91.0  2000      1   12
#
# [5 rows x 40 columns]

# %%
# 使用相关系数进行特征选择
correlation_matrix = pd.concat([X_train, y_train], axis=1).corr()

# 绘制并保存热力图
plt.figure(figsize=(30, 20))  # 设置图像大小
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title("Correlation Heatmap of Features")
plt.savefig('correlation_heatmap.png')  # 保存为PNG格式的图片
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor

# 使用随机森林模型进行特征选择
rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)

# 特征选择
feature_importance = pd.DataFrame(rf.feature_importances_, index=X.columns, columns=['Importance'])
sorted_features = feature_importance.sort_values(by='Importance', ascending=False)
print("Feature Importance:")
print(sorted_features)
# Out:
# Feature Importance:
#                  Importance
# Discharge          0.994700
# Tmax               0.000605
# Srad_lag_1         0.000575
# Vp                 0.000493
# Dayl               0.000338
# Discharge_lag_2    0.000305
# Tmax_lag_4         0.000280
# Srad_lag_7         0.000266
# Tmax_lag_5         0.000216
# Tmax_lag_1         0.000210
# Tmax_lag_2         0.000191
# Tmin               0.000188
# Prcp               0.000176
# Prcp_lag_3         0.000170
# Tmax_lag_3         0.000161
# Discharge_lag_6    0.000129
# Tmax_lag_6         0.000127
# Tmax_lag_7         0.000116
# Discharge_lag_7    0.000102
# Srad               0.000098
# Day                0.000064
# Srad_lag_2         0.000064
# Discharge_lag_3    0.000061
# Prcp_lag_1         0.000052
# Prcp_lag_7         0.000043
# Discharge_lag_1    0.000040
# Month              0.000033
# Srad_lag_4         0.000033
# Discharge_lag_4    0.000028
# Prcp_lag_6         0.000027
# Srad_lag_3         0.000026
# Discharge_lag_5    0.000021
# Srad_lag_6         0.000019
# Srad_lag_5         0.000013
# Prcp_lag_2         0.000010
# Year               0.000007
# Prcp_lag_5         0.000007
# Prcp_lag_4         0.000007

# %%
import pandas as pd
import os
import glob

# 输入文件夹路径和输出文件夹路径
input_folder = './dataset02'  # 原始数据文件夹路径
output_folder = 'data_day_4'  # 处理后数据文件夹路径

# 如果输出文件夹不存在，则创建
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# 读取所有CSV文件
all_files = glob.glob(os.path.join(input_folder, "*.csv"))

# 需要创建滞后特征的天数
num_days = 4

# 特征列
features = [ 'Prcp', 'Discharge']

# 处理每个文件
for file in all_files:
    # 读取数据
    data = pd.read_csv(file)

    # 构建滑动窗口特征
    for i in range(1, num_days + 1):
        for feature in features:
            # 创建滞后特征列，列名格式为 <特征名>_lag_<i>
            data[f'{feature}_lag_{i}'] = data[feature].shift(i)

    # 去掉包含 NaN 值的行
    data.dropna(inplace=True)

    # 生成输出文件路径
    output_file = os.path.join(output_folder, os.path.basename(file))

    # 保存处理后的数据集到新文件
    data.to_csv(output_file, index=False)

    print(f"Processed data saved to '{output_file}'.")

print("All files processed.")
# Out:
# Processed data saved to 'data_day_4\01333000.csv'.
# Processed data saved to 'data_day_4\01350000.csv'.
# Processed data saved to 'data_day_4\01350080.csv'.
# Processed data saved to 'data_day_4\01350140.csv'.
# Processed data saved to 'data_day_4\01365000.csv'.
# Processed data saved to 'data_day_4\01411300.csv'.
# Processed data saved to 'data_day_4\01413500.csv'.
# Processed data saved to 'data_day_4\01414500.csv'.
# Processed data saved to 'data_day_4\01415000.csv'.
# Processed data saved to 'data_day_4\01423000.csv'.
# Processed data saved to 'data_day_4\01434025.csv'.
# Processed data saved to 'data_day_4\01435000.csv'.
# Processed data saved to 'data_day_4\01439500.csv'.
# Processed data saved to 'data_day_4\01440000.csv'.
# Processed data saved to 'data_day_4\01440400.csv'.
# Processed data saved to 'data_day_4\01451800.csv'.
# Processed data saved to 'data_day_4\01466500.csv'.
# Processed data saved to 'data_day_4\01484100.csv'.
# Processed data saved to 'data_day_4\01485500.csv'.
# Processed data saved to 'data_day_4\01486000.csv'.
# Processed data saved to 'data_day_4\01487000.csv'.
# Processed data saved to 'data_day_4\01491000.csv'.
# Processed data saved to 'data_day_4\01510000.csv'.
# Processed data saved to 'data_day_4\01516500.csv'.
# Processed data saved to 'data_day_4\01518862.csv'.
# Processed data saved to 'data_day_4\01532000.csv'.
# Processed data saved to 'data_day_4\01539000.csv'.
# Processed data saved to 'data_day_4\01542810.csv'.
# Processed data saved to 'data_day_4\01543000.csv'.
# Processed data saved to 'data_day_4\01543500.csv'.
# Processed data saved to 'data_day_4\01544500.csv'.
# Processed data saved to 'data_day_4\01545600.csv'.
# Processed data saved to 'data_day_4\01547700.csv'.
# Processed data saved to 'data_day_4\01548500.csv'.
# Processed data saved to 'data_day_4\01549500.csv'.
# Processed data saved to 'data_day_4\01550000.csv'.
# Processed data saved to 'data_day_4\01552000.csv'.
# Processed data saved to 'data_day_4\01552500.csv'.
# Processed data saved to 'data_day_4\01557500.csv'.
# Processed data saved to 'data_day_4\01567500.csv'.
# Processed data saved to 'data_day_4\01568000.csv'.
# Processed data saved to 'data_day_4\01580000.csv'.
# Processed data saved to 'data_day_4\01583500.csv'.
# Processed data saved to 'data_day_4\01586610.csv'.
# Processed data saved to 'data_day_4\01591400.csv'.
# Processed data saved to 'data_day_4\01594950.csv'.
# Processed data saved to 'data_day_4\01596500.csv'.
# Processed data saved to 'data_day_4\01605500.csv'.
# Processed data saved to 'data_day_4\01606500.csv'.
# Processed data saved to 'data_day_4\01613050.csv'.
# Processed data saved to 'data_day_4\01620500.csv'.
# Processed data saved to 'data_day_4\01632000.csv'.
# Processed data saved to 'data_day_4\01632900.csv'.
# Processed data saved to 'data_day_4\01634500.csv'.
# Processed data saved to 'data_day_4\01638480.csv'.
# Processed data saved to 'data_day_4\01639500.csv'.
# Processed data saved to 'data_day_4\01644000.csv'.
# Processed data saved to 'data_day_4\01658500.csv'.
# Processed data saved to 'data_day_4\01664000.csv'.
# Processed data saved to 'data_day_4\01666500.csv'.
# Processed data saved to 'data_day_4\01667500.csv'.
# Processed data saved to 'data_day_4\01669000.csv'.
# Processed data saved to 'data_day_4\01669520.csv'.
# Processed data saved to 'data_day_4\02011400.csv'.
# Processed data saved to 'data_day_4\02011460.csv'.
# Processed data saved to 'data_day_4\02013000.csv'.
# Processed data saved to 'data_day_4\02014000.csv'.
# Processed data saved to 'data_day_4\02015700.csv'.
# Processed data saved to 'data_day_4\02016000.csv'.
# Processed data saved to 'data_day_4\02017500.csv'.
# Processed data saved to 'data_day_4\02018000.csv'.
# Processed data saved to 'data_day_4\02027000.csv'.
# Processed data saved to 'data_day_4\02027500.csv'.
# Processed data saved to 'data_day_4\02028500.csv'.
# Processed data saved to 'data_day_4\02038850.csv'.
# All files processed.
